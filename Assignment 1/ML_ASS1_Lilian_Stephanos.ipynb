# %% [markdown]
# **MYB NAME : Lilian steven**
#
# **gmail : liliansteven420@gmail.com**

# %% [markdown]
# ## Some notes about the data:

# %% [markdown]
# - **housingMedianAge:** Median age of a house within a block; a lower number is a newer building
#
#
# - **totalRooms:** Total number of rooms within a block
#
#
# - **totalBedrooms:** Total number of bedrooms within a block
#
#
# - **population:** Total number of people residing within a block
#
#
# - **households:** Total number of households, a group of people residing within a home unit, for a block
#
#
# - **medianIncome:** Median income for households within a block of houses (measured in tens of thousands of US Dollars)
#
#
# - **medianHouseValue:** Median house value for households within a block (measured in US Dollars)
#
#
# - **oceanProximity:** Location of the house with respect to ocean/sea

# %% [markdown]
# ## - importing the needed library :

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\Laptop\Downloads\housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0          880           129.0
# 1        -122.22     37.86                21.0         7099          1106.0
# 2        -122.24     37.85                52.0         1467           190.0
# 3        -122.25     37.85                52.0         1274           235.0
# 4        -122.25     37.85                 NaN         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0         1665           374.0
# 20636    -121.21     39.49                18.0          697           150.0
# 20637    -121.22     39.43                17.0         2254           485.0
# 20638    -121.32     39.43                18.0         1860           409.0
# 20639    -121.24     39.37                16.0         2785           616.0
#
# ...

# %% [markdown]
# ## Questions:

# %% [markdown]
# ### Q1.   How many rows and columns are in the data?

# %% [markdown]
# ## There're three methods :

# %% [markdown]
# - Count the number of rows and columns using len(df.axes[]) function.

# %%
# computing number of rows
rows = len(df.axes[0])
 
# computing number of columns
cols = len(df.axes[1])
print("Number of Rows: ", rows)
print("Number of Columns: ", cols)
# Out:
# Number of Rows:  20640
# Number of Columns:  11

# %% [markdown]
# - Count the number of rows and columns using info() function.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20382 non-null  float64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      15758 non-null  float64
#  5   population          20596 non-null  float64
#  6   households          19335 non-null  object
#  7   median_income       17873 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
#  10  gender              16620 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 1.7+ MB
# None

# %% [markdown]
# - Count the number of rows and columns using len() function.

# %%
print("Number of Rows: ", len(df))
print("Number of Columns: ", len(df.columns))
# Out:
# Number of Rows:  20640
# Number of Columns:  11

# %% [markdown]
# - Count the number of rows and columns using shape.

# %%
# obtaining the shape : NOTE : will print te number of rows and columns in dataframe 
print("shape of dataframe", df.shape)
 
# obtaining the number of rows
print("number of rows : ", df.shape[0])
 
# obtaining the number of columns
print("number of columns : ", df.shape[1])
# Out:
# shape of dataframe (20640, 11)
# number of rows :  20640
# number of columns :  11

# %% [markdown]
# ### Q2. How many null values are in each column?

# %% [markdown]
# - Checking for missing values using isnull() , and sum() function to count the number of nulls in each row

# %%
df.isnull().sum()
# Out:
# longitude                0
# latitude                 0
# housing_median_age     258
# total_rooms              0
# total_bedrooms        4882
# population              44
# households            1305
# median_income         2767
# median_house_value       0
# ocean_proximity          0
# gender                4020
# dtype: int64

# %% [markdown]
# ### Q3.   What is the column that contains the most null values?

# %% [markdown]
# - the column that contains the most null values is total_bedrooms

# %% [markdown]
# ### Q4.   What is the average number of total rooms and total bedrooms?

# %% [markdown]
# - the average of a data set,
# found by adding all numbers together and then dividing the sum of the numbers by the number of numbers
# in python we use **Python**

# %%
print('the average number of total rooms : ' , df['total_rooms'].mean())
print('the average number of total rooms : ' , df['total_bedrooms'].mean())
# Out:
# the average number of total rooms :  2635.7630813953488
# the average number of total rooms :  539.9201040741211

# %% [markdown]
# #### OR

# %%
print('the average number of total rooms : ' , df.total_rooms.mean())
print('the average number of total rooms : ' , df.total_bedrooms.mean())
# Out:
# the average number of total rooms :  2635.7630813953488
# the average number of total rooms :  539.9201040741211

# %% [markdown]
# ### Q5.   What are the different ocean proximity categories that we have?

# %% [markdown]
# - unique() function finds the unique elements of an array and returns these unique elements as a sorted array.

# %%
print(df.ocean_proximity.unique())
# Out:
# ['NEAR BAY' '<1H OCEAN' 'INLAND' 'NEAR OCEAN' 'ISLAND']

# %% [markdown]
#  ### Q6.   What is the most frequent ocean proximity?

# %% [markdown]
# - we can get the most frequently in the column by mode() function.

# %%
print(df.ocean_proximity.mode())
# Out:
# 0    <1H OCEAN
# Name: ocean_proximity, dtype: object

# %% [markdown]
# ### Q7.   What is the average median income overall?

# %%
print('the average number of total rooms : ' ,df.median_income.mean())
# Out:
# the average number of total rooms :  3.9394028646562207

# %% [markdown]
# ### Q8. What is the average population for houses in a block where the median income is more than $80,0000?

# %%
print(df[df['median_income'] >= 8.0000]['population'].mean())
#print(df.loc[df['median_income'] < 80.0000]['population'].mean())
# Out:
# 1260.6320610687023

# %% [markdown]
# ### Q9.   What is the maximum and minimum number of total rooms for houses that are located inland?

# %% [markdown]
# - maximum number of total rooms for houses that are located inland

# %%
df[df['ocean_proximity'] == 'INLAND']['total_rooms'].max()
# Out:
# 39320

# %% [markdown]
# - minimum number of total rooms for houses that are located inland

# %%
df[df['ocean_proximity'] == 'INLAND']['total_rooms'].min()
# Out:
# 2

# %% [markdown]
# ### Q10.   True or False:
# **- Q1 Houses that are located near bay have the highest average median house value. (Hint: Use `groupby()`)**
#
# **ANSWER : False**

# %% [markdown]
# **Proof of my solution:**

# %%
all_mean  = df.groupby('ocean_proximity')['median_house_value'].mean()
all_mean
# Out:
# ocean_proximity
# <1H OCEAN     240084.285464
# INLAND        124805.392001
# ISLAND        380440.000000
# NEAR BAY      259212.311790
# NEAR OCEAN    249433.977427
# Name: median_house_value, dtype: float64

# %%
max = all_mean.sort_values(ascending = False)[0]
max
# Out:
# 380440.0

# %%
NEAR_BAY_mean = df[df['ocean_proximity'] == 'NEAR BAY']['median_house_value'].mean()
NEAR_BAY_mean
# Out:
# 259212.31179039303

# %%
print(NEAR_BAY_mean == max )
# Out:
# False

# %% [markdown]
# **- Q2. The average housing median age for houses located near ocean  is more than houses located inland :**
#
# **ANSWER : True**

# %%
# NEAR OCEAN , housingMedianAge
NEAR_OCEAN_mean = df[df['ocean_proximity'] == 'NEAR OCEAN']['housing_median_age'].mean()
NEAR_OCEAN_mean
# Out:
# 29.36572504708098

# %%
INLAND_mean = df[df['ocean_proximity'] == 'INLAND']['housing_median_age'].mean()
INLAND_mean
# Out:
# 24.243495871631094

# %%
print(NEAR_OCEAN_mean > INLAND_mean)
# Out:
# True

# %% [markdown]
# **Bonus:**
#
# **- Take a look at the columns, which columns do you think are relevant to us? Are there columns that you think will not be needed?**

# %% [markdown]
# I just use a correlation matrix is tabular data representing the ‘correlations’ between pairs of variables in a given data.,
# so knowing the relationship between a column and the rest of the columns will help me to know if I can delete any of them or not

# %% [markdown]
# **MY ANSWER :**
# no , I will not delete any column. I will need them because each column has an inverse or direct relationship with the rest of the other columns.

# %%
ax = sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# **- Try to explore the data even further on your own :**

# %% [markdown]
# **(1) Understanding the big picture**

# %% [markdown]
# **1. i will use ```.describe()```**
#
# The describe function does exactly this: it provides purely descriptive information about the dataset. This information includes statistics that summarize the central tendency of the variable, their dispersion, the presence of empty values and their shape

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20382.000000  20640.000000
# mean    -119.569704     35.631861           28.676283   2635.763081
# std        2.003532      2.135952           12.589284   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population  median_income  median_house_value
# count    15758.000000  20596.000000   17873.000000        20640.000000
# mean       539.920104   1424.928724       3.939403       206855.816909
# std        419.834171   1132.237768       1.943517       115395.615874
# min          1.000000      3.000000       0.499900        14999.000000
# ...

# %% [markdown]
# Unlike ```.describe(), .info()```
# gives us a shorter summary of our dataset. It returns information about the data type, non-null values and memory usage.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20382 non-null  float64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      15758 non-null  float64
#  5   population          20596 non-null  float64
#  6   households          19335 non-null  object
#  7   median_income       17873 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
#  10  gender              16620 non-null  object
# dtypes: float64(6), int64(2), object(3)
# memory usage: 1.7+ MB

# %% [markdown]
# **l will use ```.duplicated().sum()```**
#
# To check for duplicate rows we can use .isduplicated().sum()
#
# — this will print the number of duplicated rows in our dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **l will use ```.value_counts()```**
#
# to understand how many values of a given variable there are in our dataset.

# %%
all_columns = []
for col in df.columns:
    print(f"column name : {col}\n")
    print(f"values count : {df[col].value_counts()}")
# Out:
# column name : longitude
#
# values count : -118.31    162
# -118.30    160
# -118.29    148
# -118.27    144
# -118.32    142
#           ...
# -123.54      1
# -115.94      1
# -115.99      1
# -116.81      1
# -123.71      1
# Name: longitude, Length: 844, dtype: int64
# column name : latitude
#
# values count : 34.06    244
# 34.05    236
# 34.08    234
# 34.07    231
# 34.04    221
#         ...
# 41.01      1
# 41.36      1
# 41.13      1
# 40.30      1
# 35.88      1
# Name: latitude, Length: 862, dtype: int64
# column name : housing_median_age
#
# values count : 52.0    1261
# 36.0     856
# 35.0     820
# 16.0     764
# 17.0     686
# 34.0     683
# 33.0     609
# 26.0     604
# 18.0     562
# 25.0     558
# 32.0     556
# 37.0     532
# 15.0     508
# 19.0     497
# 27.0     476
# 24.0     471
# 30.0     468
# 28.0     465
# 20.0     455
# 29.0     455
# 31.0     453
# 21.0     441
# 23.0     437
# 14.0     412
# 22.0     391
# 38.0     389
# 42.0     366
# 39.0     365
# ...

# %% [markdown]
# **plotting to see elvery column and its relation to other column in dataframe :**

# %%
sns.pairplot(df)
